# %% [markdown]
# 🔹 Step 1: Load the Dataset
# Assuming your dataset is saved as foodiebay.csv, we load it using Pandas:

# %%
import pandas as pd

# Load data
df = pd.read_csv("E:\FoodieBay DataSet\data\FoodieBay.csv")

# Preview
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/d2v-cafe-1-ba...
# 1  https://www.zomato.com/bangalore/the-burger-pl...
# 2  https://www.zomato.com/bangalore/millet-mama-b...
# 3  https://www.zomato.com/bangalore/red-onion-sha...
# 4  https://www.zomato.com/bangalore/chaiywaala-da...
#
#                                              address                 name  \
# 0  173/218, GF, Opposite Ranka Colony, Bannerghat...             D2V Cafe
# 1  2nd Floor, MMR Plaza, Above DCB Bank, Sarjapur...     The Burger Place
# 2  Next To Surana College, South End Circle, Basa...          Millet Mama
# 3  Money Chambers Double Road, Shanti Nagar, Bang...            Red Onion
# 4  Shop 67, 69, 70, Inside Ramaiah Campus, New BE...  Chaiywaala Da Dhaba
#
#                             phone               location      rest_type  \
# 0  +91 9886986111\n+91 8550051111      Bannerghatta Road           Cafe
# 1                  +91 9108974600  Koramangala 1st Block    Quick Bites
# 2  +91 7411918648\n+91 9986975625           Basavanagudi    Quick Bites
# 3                  +91 8867253669           Shanti Nagar  Casual Dining
# 4  +91 8217431260\n+91 7975991975           New BEL Road           Cafe
#
#                                 cuisines  \
# 0                                   Cafe
# 1         Burger, Continental, Fast Food
# 2             South Indian, Healthy Food
# 3  Chinese, North Indian, Biryani, Kebab
# 4                              Cafe, Tea
#
#                                            menu_item listed_in_type  \
# 0                                                 []          Cafes
# 1                                                 []       Dine-out
# 2                                                 []       Delivery
# 3  ['Hyderabadi Biryani', 'Special Veg Combo', 'S...       Delivery
# 4                                                 []       Dine-out
#
#           listed_in_city online_order book_table  ave_cost_for_two  \
# 0               JP Nagar           No         No             700.0
# 1  Koramangala 5th Block          Yes         No             400.0
# 2              Jayanagar          Yes         No             200.0
# 3           Brigade Road          Yes        Yes            1200.0
# 4           New BEL Road          Yes         No             250.0
#
#                                           dish_liked  votes  \
# 0                                                NaN     13
# 1                                                NaN     28
# 2                                                NaN     18
# 3  Fish, Dumplings, Biryani, Paneer Tikka Masala,...    550
# 4  Ginger Chai, Pakoda, Tea, Paneer Thali, Chole ...     67
#
#    ave_review_ranking  rate
# 0                4.75   3.6
# 1                4.50   3.8
# 2                4.00   3.9
# 3                4.80   4.3
# 4                3.00   3.7

# %% [markdown]
# 🔹 Step 2: Understand Columns and Missing Data

# %%
# Overview of data
df.info()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40130 entries, 0 to 40129
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   url                 40130 non-null  object
#  1   address             40130 non-null  object
#  2   name                40130 non-null  object
#  3   phone               39246 non-null  object
#  4   location            40130 non-null  object
#  5   rest_type           40130 non-null  object
#  6   cuisines            40112 non-null  object
#  7   menu_item           40130 non-null  object
#  8   listed_in_type      40130 non-null  object
#  9   listed_in_city      40130 non-null  object
#  10  online_order        40130 non-null  object
#  11  book_table          40130 non-null  object
#  12  ave_cost_for_two    39890 non-null  float64
#  13  dish_liked          17351 non-null  object
#  14  votes               40130 non-null  int64
#  15  ave_review_ranking  33751 non-null  float64
#  16  rate                31794 non-null  float64
# dtypes: float64(3), int64(1), object(13)
# memory usage: 5.2+ MB
# url                       0
# address                   0
# name                      0
# phone                   884
# location                  0
# rest_type                 0
# cuisines                 18
# menu_item                 0
# listed_in_type            0
# listed_in_city            0
# online_order              0
# book_table                0
# ave_cost_for_two        240
# dish_liked            22779
# votes                     0
# ave_review_ranking     6379
# rate                   8336
# dtype: int64

# %% [markdown]
# 🔹 Step 3: Clean Columns One-by-One
# 🧽 Clean rate and ave_review_ranking

# %%
df['cuisines'] = df['cuisines'].fillna('Unknown')
df['ave_cost_for_two'] = df['ave_cost_for_two'].fillna(df['ave_cost_for_two'].median())
df['dish_liked'] = df['dish_liked'].fillna('Not Specified')
df['ave_review_ranking'] = df['ave_review_ranking'].fillna(df['ave_review_ranking'].median())
df['rate'] = df['rate'].fillna(df['rate'].median())

# %%
# Remove '/5', strip whitespace, convert to float
df['rate'] = df['rate'].astype(str).str.replace('/5', '').str.strip()
df['rate'] = df['rate'].replace('NEW', None).replace('-', None)
df['rate'] = df['rate'].astype(float)

# Convert ave_review_ranking to float
df['ave_review_ranking'] = pd.to_numeric(df['ave_review_ranking'], errors='coerce')

# %% [markdown]
# 🔢 Convert votes, ave_cost_for_two

# %%
df['votes'] = pd.to_numeric(df['votes'], errors='coerce')
df['ave_cost_for_two'] = pd.to_numeric(df['ave_cost_for_two'], errors='coerce')

# %% [markdown]
# 🔁 Handle Yes/No in online_order and book_table

# %%
df['online_order'] = df['online_order'].map({'Yes': 1, 'No': 0})
df['book_table'] = df['book_table'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# 🧹 Clean cuisines, dish_liked
# These are text-based lists. You can either keep them as-is or extract top features later.
#
# Example: Count most common cuisine styles:
#
# python
# Copy
# Edit

# %%
from collections import Counter

# Example: Top 10 cuisines
all_cuisines = df['cuisines'].dropna().str.split(', ').sum()
cuisine_counts = pd.Series(all_cuisines).value_counts().head(10)

# %% [markdown]
# If needed, we can one-hot encode popular cuisines later.

# %% [markdown]
# 🧹 Clean menu_item
# Some entries are empty or massive arrays. You can:
#
# Drop this column for modeling
#
# Extract only counts (e.g., number of items)

# %%
df['menu_item_count'] = df['menu_item'].apply(lambda x: len(eval(x)) if isinstance(x, str) and x.startswith('[') else 0)
df.drop(columns=['menu_item'], inplace=True)

# %% [markdown]
# 🏷️ Encode Categorical Features
# Columns like location, rest_type, listed_in_city, listed_in_type → one-hot or label encoding:

# %%
# Option 1: Label Encoding (for tree models)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in ['location', 'rest_type', 'listed_in_type', 'listed_in_city']:
    df[col] = le.fit_transform(df[col].astype(str))

# %% [markdown]
# ✅ Final Step: Drop Unused Columns

# %%
df.drop(columns=['url', 'address', 'phone', 'name', 'dish_liked'], inplace=True)

# %% [markdown]
# df.info()
# df.describe()

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40130 entries, 0 to 40129
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   location            40130 non-null  int64
#  1   rest_type           40130 non-null  int64
#  2   cuisines            40130 non-null  object
#  3   listed_in_type      40130 non-null  int64
#  4   listed_in_city      40130 non-null  int64
#  5   online_order        40130 non-null  int64
#  6   book_table          40130 non-null  int64
#  7   ave_cost_for_two    40130 non-null  float64
#  8   votes               40130 non-null  int64
#  9   ave_review_ranking  40130 non-null  float64
#  10  rate                40130 non-null  float64
#  11  menu_item_count     40130 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 3.7+ MB
#            location     rest_type  listed_in_type  listed_in_city  \
# count  40130.000000  40130.000000    40130.000000    40130.000000
# mean      35.374009      3.641964        2.749439       14.070994
# std       27.336681      1.703521        1.094749        8.244336
# min        0.000000      0.000000        0.000000        0.000000
# 25%        9.000000      2.000000        2.000000        7.000000
# 50%       32.000000      5.000000        2.000000       15.000000
# 75%       55.000000      5.000000        4.000000       20.000000
# max       92.000000      6.000000        6.000000       29.000000
#
#        online_order    book_table  ave_cost_for_two         votes  \
# count  40130.000000  40130.000000      40130.000000  40130.000000
# mean       0.611986      0.102018        506.059183    225.685547
# std        0.487304      0.302676        323.298238    598.568781
# min        0.000000      0.000000         40.000000      0.000000
# 25%        0.000000      0.000000        300.000000      6.000000
# 50%        1.000000      0.000000        400.000000     36.000000
# 75%        1.000000      0.000000        600.000000    174.000000
# max        1.000000      1.000000       2500.000000  12121.000000
#
#        ave_review_ranking          rate  menu_item_count
# count        40130.000000  40130.000000     40130.000000
# mean             3.610388      3.666150        26.936058
# std              0.839315      0.384137        64.301264
# min              1.000000      1.800000         0.000000
# 25%              3.200000      3.500000         0.000000
# 50%              3.727273      3.700000         0.000000
# 75%              4.000000      3.900000         0.000000
# max              5.000000      4.900000       715.000000

# %%
df.head()
# Out:
#    location  rest_type                               cuisines  listed_in_type  \
# 0         3          1                                   Cafe               1
# 1        41          5         Burger, Continental, Fast Food               4
# 2         4          5             South Indian, Healthy Food               2
# 3        78          2  Chinese, North Indian, Biryani, Kebab               2
# 4        60          1                              Cafe, Tea               4
#
#    listed_in_city  online_order  book_table  ave_cost_for_two  votes  \
# 0              12             0           0             700.0     13
# 1              17             1           0             400.0     28
# 2              13             1           0             200.0     18
# 3               5             1           1            1200.0    550
# 4              24             1           0             250.0     67
#
#    ave_review_ranking  rate  menu_item_count
# 0                4.75   3.6                0
# 1                4.50   3.8                0
# 2                4.00   3.9                0
# 3                4.80   4.3              100
# 4                3.00   3.7                0

# %% [markdown]
# # Use top N cuisines (better, keeps more info)

# %%
# Count cuisines (take first cuisine from list for consistency)
df['primary_cuisine'] = df['cuisines'].apply(lambda x: x.split(',')[0].strip())

# Keep top 20 cuisines, rest as "Other"
top_cuisines = df['primary_cuisine'].value_counts().nlargest(20).index
df['primary_cuisine'] = df['primary_cuisine'].apply(lambda x: x if x in top_cuisines else 'Other')

# %%
df = pd.get_dummies(df, columns=['primary_cuisine'], drop_first=True)

# %%
df = df.drop(columns=['cuisines'])

# %%
df.head()
# Out:
#    location  rest_type  listed_in_type  listed_in_city  online_order  \
# 0         3          1               1              12             0
# 1        41          5               4              17             1
# 2         4          5               2              13             1
# 3        78          2               2               5             1
# 4        60          1               4              24             1
#
#    book_table  ave_cost_for_two  votes  ave_review_ranking  rate  ...  \
# 0           0             700.0     13                4.75   3.6  ...
# 1           0             400.0     28                4.50   3.8  ...
# 2           0             200.0     18                4.00   3.9  ...
# 3           1            1200.0    550                4.80   4.3  ...
# 4           0             250.0     67                3.00   3.7  ...
#
#    primary_cuisine_Fast Food  primary_cuisine_Healthy Food  \
# 0                      False                         False
# 1                      False                         False
# 2                      False                         False
# 3                      False                         False
# 4                      False                         False
#
#    primary_cuisine_Italian  primary_cuisine_Kerala  \
# 0                    False                   False
# 1                    False                   False
# 2                    False                   False
# 3                    False                   False
# 4                    False                   False
#
#    primary_cuisine_North Indian  primary_cuisine_Other  primary_cuisine_Pizza  \
# 0                         False                  False                  False
# 1                         False                  False                  False
# 2                         False                  False                  False
# 3                         False                  False                  False
# 4                         False                  False                  False
#
#    primary_cuisine_Seafood  primary_cuisine_South Indian  \
# 0                    False                         False
# 1                    False                         False
# 2                    False                          True
# 3                    False                         False
# 4                    False                         False
#
#    primary_cuisine_Street Food
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
# [5 rows x 31 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40130 entries, 0 to 40129
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   location                      40130 non-null  int64
#  1   rest_type                     40130 non-null  int64
#  2   listed_in_type                40130 non-null  int64
#  3   listed_in_city                40130 non-null  int64
#  4   online_order                  40130 non-null  int64
#  5   book_table                    40130 non-null  int64
#  6   ave_cost_for_two              40130 non-null  float64
#  7   votes                         40130 non-null  int64
#  8   ave_review_ranking            40130 non-null  float64
#  9   rate                          40130 non-null  float64
#  10  menu_item_count               40130 non-null  int64
#  11  primary_cuisine_Arabian       40130 non-null  bool
#  12  primary_cuisine_Asian         40130 non-null  bool
#  13  primary_cuisine_Bakery        40130 non-null  bool
#  14  primary_cuisine_Bengali       40130 non-null  bool
#  15  primary_cuisine_Biryani       40130 non-null  bool
#  16  primary_cuisine_Burger        40130 non-null  bool
#  17  primary_cuisine_Cafe          40130 non-null  bool
#  18  primary_cuisine_Chinese       40130 non-null  bool
#  19  primary_cuisine_Continental   40130 non-null  bool
#  20  primary_cuisine_Desserts      40130 non-null  bool
#  21  primary_cuisine_Fast Food     40130 non-null  bool
#  22  primary_cuisine_Healthy Food  40130 non-null  bool
#  23  primary_cuisine_Italian       40130 non-null  bool
#  24  primary_cuisine_Kerala        40130 non-null  bool
#  25  primary_cuisine_North Indian  40130 non-null  bool
#  26  primary_cuisine_Other         40130 non-null  bool
#  27  primary_cuisine_Pizza         40130 non-null  bool
#  28  primary_cuisine_Seafood       40130 non-null  bool
#  29  primary_cuisine_South Indian  40130 non-null  bool
#  30  primary_cuisine_Street Food   40130 non-null  bool
# dtypes: bool(20), float64(3), int64(8)
# memory usage: 4.1 MB
#            location     rest_type  listed_in_type  listed_in_city  \
# count  40130.000000  40130.000000    40130.000000    40130.000000
# mean      35.374009      3.641964        2.749439       14.070994
# std       27.336681      1.703521        1.094749        8.244336
# min        0.000000      0.000000        0.000000        0.000000
# 25%        9.000000      2.000000        2.000000        7.000000
# 50%       32.000000      5.000000        2.000000       15.000000
# 75%       55.000000      5.000000        4.000000       20.000000
# max       92.000000      6.000000        6.000000       29.000000
#
#        online_order    book_table  ave_cost_for_two         votes  \
# count  40130.000000  40130.000000      40130.000000  40130.000000
# mean       0.611986      0.102018        506.059183    225.685547
# std        0.487304      0.302676        323.298238    598.568781
# min        0.000000      0.000000         40.000000      0.000000
# 25%        0.000000      0.000000        300.000000      6.000000
# 50%        1.000000      0.000000        400.000000     36.000000
# 75%        1.000000      0.000000        600.000000    174.000000
# max        1.000000      1.000000       2500.000000  12121.000000
#
#        ave_review_ranking          rate  menu_item_count
# count        40130.000000  40130.000000     40130.000000
# mean             3.610388      3.666150        26.936058
# std              0.839315      0.384137        64.301264
# min              1.000000      1.800000         0.000000
# 25%              3.200000      3.500000         0.000000
# 50%              3.727273      3.700000         0.000000
# 75%              4.000000      3.900000         0.000000
# max              5.000000      4.900000       715.000000

# %%
# Convert all boolean columns to int
df = df.astype({col: 'int' for col in df.columns if df[col].dtype == 'bool'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40130 entries, 0 to 40129
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   location                      40130 non-null  int64
#  1   rest_type                     40130 non-null  int64
#  2   listed_in_type                40130 non-null  int64
#  3   listed_in_city                40130 non-null  int64
#  4   online_order                  40130 non-null  int64
#  5   book_table                    40130 non-null  int64
#  6   ave_cost_for_two              40130 non-null  float64
#  7   votes                         40130 non-null  int64
#  8   ave_review_ranking            40130 non-null  float64
#  9   rate                          40130 non-null  float64
#  10  menu_item_count               40130 non-null  int64
#  11  primary_cuisine_Arabian       40130 non-null  int64
#  12  primary_cuisine_Asian         40130 non-null  int64
#  13  primary_cuisine_Bakery        40130 non-null  int64
#  14  primary_cuisine_Bengali       40130 non-null  int64
#  15  primary_cuisine_Biryani       40130 non-null  int64
#  16  primary_cuisine_Burger        40130 non-null  int64
#  17  primary_cuisine_Cafe          40130 non-null  int64
#  18  primary_cuisine_Chinese       40130 non-null  int64
#  19  primary_cuisine_Continental   40130 non-null  int64
#  20  primary_cuisine_Desserts      40130 non-null  int64
#  21  primary_cuisine_Fast Food     40130 non-null  int64
#  22  primary_cuisine_Healthy Food  40130 non-null  int64
#  23  primary_cuisine_Italian       40130 non-null  int64
#  24  primary_cuisine_Kerala        40130 non-null  int64
#  25  primary_cuisine_North Indian  40130 non-null  int64
#  26  primary_cuisine_Other         40130 non-null  int64
#  27  primary_cuisine_Pizza         40130 non-null  int64
#  28  primary_cuisine_Seafood       40130 non-null  int64
#  29  primary_cuisine_South Indian  40130 non-null  int64
#  30  primary_cuisine_Street Food   40130 non-null  int64
# dtypes: float64(3), int64(28)
# memory usage: 9.5 MB

# %%
df.to_csv(r"E:\FoodieBay DataSet\data\foodiebay_cleaned.csv", index=False)
